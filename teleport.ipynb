# %%
from bs4 import BeautifulSoup
import requests

# %%
teleport_infile = 'OTB-Teleport-web.html'

# %%
infile = open(file = teleport_infile, mode = 'r')

# %%
soup = BeautifulSoup(markup = infile, features = 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=2.0" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://otbdiscs.com/xmlrpc.php" rel="pingback"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <script>
#     window._wca = window._wca || [];
#    </script>
#    <!-- This site is optimized with the Yoast SEO Premium plugin v17.6 (Yoast SEO v17.6) - https://yoast.com/wordpress/plugins/seo/ -->
#    <title>
#     Teleport - Only the Best Discs
#    </title>
#    <link href="https://otbdiscs.com/product/teleport/" rel="canonical">
#     <meta content="en_US" property="og:locale">
#      <meta content="article" property="og:type"/>
#      <meta content="Teleport" property="og:title"/>
# ...

# %%
scaled_weight = soup.findAll(name='td', attrs={'class' : 'optionscol attribute_pa_weight'})
print(scaled_weight)

# %%
for weight in scaled_weight:
    print(weight.string)

# %%
scaled = []
for weight in scaled_weight:
    weight_string = weight.string
    weight_string = scaled_weight.replace('g', '')
    weight_string = scaled_weight.replace('173-175', '174')
    scale = float(weight_string)
    advertised.append(scale)

# %%
print(scaled)
